# %% [markdown]
# # Shot Angle And Level Classifiyer Implemented

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import cv2
import seaborn as sns
import glob
import xml.etree.ElementTree as ET
from PIL import Image
import os
import shutil
import torch

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.17  Python-3.12.6 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 16384MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 580.3/931.0 GB disk)

# %%
from ultralytics import YOLO

# %% [markdown]
# ## Model Assignment

# %%
level_model = YOLO('Models/level/level_75epoch.pt')

# %%
angle_model = YOLO('Models/angle/angle_lr0-001.pt')

# %% [markdown]
# ## Show Testing

# %%
#Import photo from a directory 
import os, random 
image_dir = 'Raw Datasets/OtherTests'
image_file = image_dir + '/' + random.choice(os.listdir(image_dir))

print(image_file)
# Out:
# Raw Datasets/OtherTests/headspace_3.png

# %%
import os, glob, random
def randomized_sample(raw_path, sample_size):
    path_list = []
    for i in range(sample_size):
        folder = raw_path + '/' + random.choice(os.listdir(raw_path))
        file = folder +'/' + random.choice(os.listdir(folder))
        path_list.append(file)
    return path_list

# %%
angle_model(image_file, save=True)
# Out:
# image 1/1 C:\Users\alex\Documents\SFU Courses\FALL 2024\IAT 360\Work\CVProject-ShotAngle_LevelClassifier\Raw Datasets\OtherTests\headspace_3.png: 224x224 neutral 0.59, low 0.36, high 0.03, dutch 0.02, overhead 0.00, 3.5ms
# Speed: 17.2ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs\classify\predict7
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: None
#  keypoints: None
#  masks: None
#  names: {0: 'dutch', 1: 'high', 2: 'low', 3: 'neutral', 4: 'overhead'}
#  obb: None
#  orig_img: array([[[75, 77, 77],
#          [75, 77, 77],
#          [75, 77, 77],
#          ...,
#          [69, 75, 76],
#          [69, 75, 76],
#          [69, 75, 76]],
#
#         [[77, 79, 79],
#          [77, 79, 79],
#          [77, 79, 79],
#          ...,
#          [71, 77, 78],
#          [71, 77, 78],
#          [71, 77, 78]],
#
#         [[78, 79, 79],
#          [78, 79, 79],
#          [78, 79, 79],
# ...

# %%
# %matplotlib inline
from PIL import Image

#show predicted image
image = os.path.basename(image_file) 
if '.png' in image:
    image = image.replace('.png', '.jpg')
predicted_image = 'runs/classify/predict7/' + image
Image.open(predicted_image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080>

# %%
# space for testing 
level_test_path = 'level_data/test'
angle_test_path = 'angle_data/test'

# %%
# Import image from link 
# image_file = 'https://4192879.fs1.hubspotusercontent-na1.net/hub/4192879/hubfs/Blog%20Images/2021/April/Blog-March-LowAngle.jpg?width=944&height=590&name=Blog-March-LowAngle.jpg'

# %%
# random test data
rand_level_test = randomized_sample(level_test_path, 5)
rand_angle_test = randomized_sample(angle_test_path, 5)

# %%
for path in rand_level_test:
    level_model(path, save=True)
# Out:
# image 1/1 C:\Users\alex\Documents\SFU Courses\FALL 2024\IAT 360\Work\CVProject-ShotAngle_LevelClassifier\level_data\test\aerial\aerial_01890.png: 224x224 aerial 1.00, ground-knee 0.00, hip 0.00, shoulder 0.00, eye 0.00, 4.6ms
# Speed: 6.0ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs\classify\predict6
#
# image 1/1 C:\Users\alex\Documents\SFU Courses\FALL 2024\IAT 360\Work\CVProject-ShotAngle_LevelClassifier\level_data\test\shoulder\shoulder_01434.jpg: 224x224 eye 0.58, shoulder 0.42, hip 0.00, ground-knee 0.00, aerial 0.00, 4.5ms
# Speed: 5.0ms preprocess, 4.5ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs\classify\predict6
#
# image 1/1 C:\Users\alex\Documents\SFU Courses\FALL 2024\IAT 360\Work\CVProject-ShotAngle_LevelClassifier\level_data\test\aerial\aerial_03823.png: 224x224 aerial 1.00, ground-knee 0.00, eye 0.00, shoulder 0.00, hip 0.00, 5.5ms
# ...

# %%
for path in rand_angle_test:
    angle_model(path, save=True)
# Out:
# image 1/1 C:\Users\alex\Documents\SFU Courses\FALL 2024\IAT 360\Work\CVProject-ShotAngle_LevelClassifier\angle_data\test\low\low_00475.jpg: 224x224 low 0.87, high 0.12, dutch 0.01, neutral 0.00, overhead 0.00, 5.0ms
# Speed: 5.2ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs\classify\predict
#
# image 1/1 C:\Users\alex\Documents\SFU Courses\FALL 2024\IAT 360\Work\CVProject-ShotAngle_LevelClassifier\angle_data\test\dutch\dutch_00192.jpg: 224x224 dutch 0.94, high 0.06, low 0.00, neutral 0.00, overhead 0.00, 4.9ms
# Speed: 106.9ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs\classify\predict
#
# image 1/1 C:\Users\alex\Documents\SFU Courses\FALL 2024\IAT 360\Work\CVProject-ShotAngle_LevelClassifier\angle_data\test\low\low_00204.jpg: 224x224 low 1.00, dutch 0.00, high 0.00, overhead 0.00, neutral 0.00, 4.3ms
# ...

# %%
# SHOW THE IMAGE STORED
# %matplotlib inline
from PIL import Image
import random, os

#show image for angle prediction
img = 'runs/classify/predict/' + random.choice(os.listdir('runs/classify/predict'))
print(img)
Image.open(img)
# Out:
# runs/classify/predict/gen_dutch_00041.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=624x464>

# %%
#show predicted image for level
img2 ='runs/classify/predict6/' + random.choice(os.listdir('runs/classify/predict6')) 
print(img2)
Image.open(img2)
# Out:
# runs/classify/predict6/aerial_01890.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=854x480>
